# %%
# autoreload
# %load_ext autoreload
# %autoreload 2
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from SillyBayesianScreeningSearch.BayesLearn import median_bayes_learn

B = 100
N = 1000
M = 500
alpha = 0.01
# generate N random data in [B]
D = np.random.randint(0, B-1, N)
print("Median of D: ", np.median(D))
# Out:
# Median of D:  51.0

# %%
L = median_bayes_learn(D=D, M=M, alpha=alpha, replacement=False)
print("Median of L: ", np.median(L))
# Out:
# round 0: interval 499, coin 499
# round 1: interval 489, coin 489
# round 2: interval 480, coin 480
# round 3: interval 470, coin 470
# round 4: interval 461, coin 461
# round 5: interval 452, coin 452
# round 6: interval 443, coin 443
# round 7: interval 434, coin 434
# round 8: interval 426, coin 426
# round 9: interval 417, coin 417
# round 10: interval 409, coin 409
# round 11: interval 401, coin 401
# round 12: interval 393, coin 393
# round 13: interval 386, coin 386
# round 14: interval 378, coin 378
# round 15: interval 371, coin 371
# round 16: interval 363, coin 363
# round 17: interval 356, coin 356
# round 18: interval 349, coin 349
# round 19: interval 342, coin 342
# round 20: interval 336, coin 336
# round 21: interval 329, coin 329
# round 22: interval 323, coin 323
# round 23: interval 316, coin 316
# round 24: interval 310, coin 310
# round 25: interval 304, coin 304
# round 26: interval 298, coin 298
# round 27: interval 292, coin 292
# ...

# %%
# get the 0.5 quantile of L
# Out:
# 51.0

# %%
import matplotlib.pyplot as plt
plt.hist(L, bins=100, density=True)
plt.xlim(0,100)
plt.show()
