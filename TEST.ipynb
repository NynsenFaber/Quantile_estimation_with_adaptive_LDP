# %%
# autoreload
# %load_ext autoreload
# %autoreload 2
import numpy as np

# %%
from SillyBayesianScreeningSearch.MedianBayesLearn import bayes_learn

B = 100
N = 1000
M = 500
alpha = 0.1
# generate N random data in [B]
D = np.random.randint(0, B-1, N)
print("Median of D: ", np.median(D))
# Out:
# Median of D:  49.5

# %%
L = bayes_learn(D=D, B=B, M=M, alpha=alpha)
# Out:
# round 0: interval 499, coin 499
# round 1: interval 416, coin 416
# round 2: interval 346, coin 346
# round 3: interval 289, coin 289
# round 4: interval 240, coin 240
# round 5: interval 200, coin 200
# round 6: interval 167, coin 167
# round 7: interval 139, coin 139
# round 8: interval 116, coin 116
# round 9: interval 96, coin 96
# round 10: interval 112, coin 112
# round 11: interval 99, coin 99
# round 12: interval 84, coin 84
# round 13: interval 70, coin 70
# round 14: interval 81, coin 81
# round 15: interval 71, coin 71
# round 16: interval 60, coin 60
# round 17: interval 50, coin 50
# round 18: interval 42, coin 42
# round 19: interval 35, coin 35
# round 20: interval 29, coin 29
# round 21: interval 34, coin 34
# round 22: interval 39, coin 39
# round 23: interval 46, coin 46
# round 24: interval 40, coin 40
# round 25: interval 35, coin 35
# round 26: interval 40, coin 40
# round 27: interval 44, coin 44
# round 28: interval 40, coin 40
# round 29: interval 37, coin 37
# ...

# %%
# get the 0.5 quantile of L
np.quantile(L, 0.5)
# Out:
# 45.0
